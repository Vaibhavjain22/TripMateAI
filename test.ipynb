# %%
from Tools.tavily_tool import tavily_search

# %%
results=tavily_search("best hotels in jaipur")['results']

for i in range(0,len(results)):
    print(results[i]['content'])
# Out:
# ### SAMODE HAVELI
#
# Samode Haveli is the best hotel in Jaipur if you're looking for an intimate royal retreat close to all the city sights. The opulence of the hotel's interior is seen among private courtyards, grandeur fountains, and one of the prettiest pools in Jaipur.
#
# Inside, richly-textured mahogany furnishings, antique arches, and golden details add a touch of elegance making you feel like you're in a glistening Bollywood movie with glamorous backdrops.
#
# THE DETAILS [...] One of the best places to stay in Jaipur to experience luxury without breaking the bank is Alsisar Haveli Heritage Hotel. Tucked right into the heart of Jaipur's walled city, this enchanting mansion is re-shaped into a contemporary garden of delights.
#
# Boasting tastefully decorated and well-equipped heritage-style rooms, you'll have plenty of space to make yourself at home among this ambience of opulence and pure decadence.
#
# THE DETAILS
#
# Where | Alsisar Haveli, Sansar Chandra Road, Jaipur [...] With its central location and world-class amenities, Jai Mahal Palace remains as one of the best luxury hotels in Jaipur. The colonial-style interior perfectly blends irresistible 18th-century charm with 21st-century comfort offering the best of Rajasthani heritage and culture.
#
# Staying in their thematic suites with opulent antique furniture and a mix of wooden and golden details will make you feel like royalty. The luxurious, marble bathrooms are also nothing less impressive.
#
# THE DETAILS
# Close to the Amer Fort, Fairmont is the top-drawer Jaipur hotel for family vacations, honeymooners, world-class events, and destination weddings. If personalisation is modern-day luxury, then Fairmont raises the bar with the ‘six senses welcome ceremony’ that it rolls out for every guest. The Fairmont Terrace Suite has one of the most extensive terraces, with a private room and great views. With a circular granite bathtub full of rose petals, exotic flowers, fresh oranges, and neem, [...] book now
#
#   Hotels in Kukas
#   Kukas has become a hub of the best hotels in Jaipur. This quaint industrial town, located on the outskirts of Jaipur, has an array of resorts and hotels from many major national and international brands. The strategic location of Kukas, perched along the corridor of picturesque mountains close to Amber, is directly adjacent to the Jaipur-Delhi national highway, transforming the location into a tourist, business, wedding, and events hotspot.
#  Himanshu Lakhwani [...] With winding walkways shaded by swaying trees, meandering past shimmering lotus ponds and regal fountains, The Leela Palace Jaipur is a majestic haven that caters to your most discerning desires–think de rigueur destination weddings, regal retreats, and serene escapes. Offering private butlers, gambolling golf carts, multiple restaurants, and a state-of-the-art spa, this place is straight-up divine. With a private pool, gazebo bed, mini waterfall, and outdoor seating, the Royal Villas of
# The travel club
#
# Mr. & Mrs. Smith
#
# E-Gift Cart   Physical gift card
#
# Join the club
#
# Trustpilot
#
#  9 Hotels
#  0 Villas
#  Explore
#
# # Best boutique and luxury hotels in Jaipur
#
# 1. Photo of Royal Heritage Haveli    Photo of Royal Heritage Haveli    Photo of Royal Heritage Haveli    Photo of Royal Heritage Haveli    Photo of Royal Heritage Haveli
#
#    Offers available
#
#    Jaipur, India
#
#    ## Royal Heritage Haveli
#
#    ### Smith Extra

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(
    model="gpt-4o-mini",
    
)

query="what is the capital of India"

response=llm.invoke(query)
print(response.content)
# Out:
# The capital of India is New Delhi.

# %%
from Tools.flight_tool import search_flights

result= search_flights("plan a 7 day trip from india to nepal")

print(result)
# Out:
# Live flights from DEL to KTM
#
# Airline: Air India
# Flight: AI223
# Status: scheduled
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 4
# - Scheduled: 2026-09-06T22:05:00+00:00
# - Delay: N/A
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-07T00:05:00+00:00
# - Delay: N/A
#
# ---
#
# Airline: Air India
# Flight: AI211
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 14B
# - Scheduled: 2026-09-06T18:15:00+00:00
# - Delay: 2 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T20:10:00+00:00
# - Delay: N/A
#
# ---
#
# Airline: IndiGo
# Flight: 6E1161
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 17B
# - Scheduled: 2026-09-06T17:50:00+00:00
# - Delay: 9 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T19:50:00+00:00
# - Delay: 9 minutes
#
# ---
#
# Airline: Nepal Airlines
# Flight: RA218
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 9B
# - Scheduled: 2026-09-06T16:20:00+00:00
# - Delay: 1 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T18:10:00+00:00
# - Delay: 1 minutes
#
# ---
#
# Airline: Qantas
# Flight: QF5213
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 9B
# - Scheduled: 2026-09-06T13:40:00+00:00
# - Delay: 13 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T15:40:00+00:00
# - Delay: 13 minutes
#
# ---
#
# Airline: Air India
# Flight: AI219
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 9A
# - Scheduled: 2026-09-06T14:25:00+00:00
# - Delay: 49 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T16:30:00+00:00
# - Delay: 49 minutes
#
# ---
#
# Airline: IndiGo
# Flight: 6E1155
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 9B
# - Scheduled: 2026-09-06T13:40:00+00:00
# - Delay: 13 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T15:40:00+00:00
# - Delay: 13 minutes
#
# ---
#
# Airline: KLM
# Flight: KL4384
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 6
# - Scheduled: 2026-09-06T11:10:00+00:00
# - Delay: 5 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T13:05:00+00:00
# - Delay: 5 minutes
#
# ---
#
# Airline: Qantas
# Flight: QF5212
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 6
# - Scheduled: 2026-09-06T11:10:00+00:00
# - Delay: 5 minutes
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T13:05:00+00:00
# - Delay: 5 minutes
#
# ---
#
# Airline: Air India
# Flight: AI217
# Status: landed
#
# Departure:
# - Airport: Indira Gandhi International
# - IATA: DEL
# - Terminal: 3
# - Gate: 9B
# - Scheduled: 2026-09-06T11:35:00+00:00
# - Delay: N/A
#
# Arrival:
# - Airport: Tribhuvan International
# - IATA: KTM
# - Terminal: I
# - Gate: N/A
# - Scheduled: 2026-09-06T13:40:00+00:00
# - Delay: N/A
